# %%
import random
import pandas as pd

from implementations import *
from helpers import *

path_to_dataset = "data/dataset/"

df = pd.read_csv(path_to_dataset + "x_train.csv")
x_test = pd.read_csv(path_to_dataset + "x_test.csv")
y_train = pd.read_csv(path_to_dataset + "y_train.csv")

# %%
print(df.shape)       # number of rows and columns
print(df.info())      # types, null counts
df.describe()  # basic stats for numerical features
# Out:
# (328135, 322)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328135 entries, 0 to 328134
# Columns: 322 entries, Id to _AIDTST3
# dtypes: float64(244), int64(78)
# memory usage: 806.1 MB
# None
#                   Id         _STATE         FMONTH         IDATE  \
# count  328135.000000  328135.000000  328135.000000  3.281350e+05
# mean   164067.000000      29.973651       6.360690  6.563638e+06
# std     94724.559628      16.031777       3.487263  3.489248e+06
# min         0.000000       1.000000       1.000000  1.012016e+06
# 25%     82033.500000      19.000000       3.000000  3.232015e+06
# 50%    164067.000000      29.000000       6.000000  6.242015e+06
# 75%    246100.500000      44.000000       9.000000  1.002202e+07
# max    328134.000000      72.000000      12.000000  1.231202e+07
#
#               IMONTH           IDAY          IYEAR       DISPCODE  \
# count  328135.000000  328135.000000  328135.000000  328135.000000
# mean        6.416661      14.496235    2015.024758    1115.014857
# std         3.492739       8.334495       0.155387      35.721753
# min         1.000000       1.000000    2015.000000    1100.000000
# 25%         3.000000       8.000000    2015.000000    1100.000000
# 50%         6.000000      14.000000    2015.000000    1100.000000
# 75%        10.000000      21.000000    2015.000000    1100.000000
# max        12.000000      31.000000    2016.000000    1200.000000
#
#               SEQNO          _PSU  ...        _PAREC1       _PASTAE1  \
# count  3.281350e+05  3.281350e+05  ...  328135.000000  328135.000000
# mean   2.015005e+09  2.015005e+09  ...       3.488567       2.737611
# std    4.118475e+03  4.118475e+03  ...       2.395363       2.445086
# min    2.015000e+09  2.015000e+09  ...       1.000000       1.000000
# 25%    2.015002e+09  2.015002e+09  ...       2.000000       2.000000
# 50%    2.015004e+09  2.015004e+09  ...       3.000000       2.000000
# 75%    2.015007e+09  2.015007e+09  ...       4.000000       2.000000
# max    2.015023e+09  2.015023e+09  ...       9.000000       9.000000
#
#             _LMTACT1       _LMTWRK1       _LMTSCL1       _RFSEAT2  \
# count  326252.000000  326252.000000  326252.000000  328135.000000
# mean        2.717093       2.814279       3.652698       1.820421
# std         1.317887       1.348067       1.259353       2.355332
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       2.000000       3.000000       1.000000
# 50%         3.000000       3.000000       4.000000       1.000000
# 75%         3.000000       3.000000       4.000000       1.000000
# max         9.000000       9.000000       9.000000       9.000000
#
#             _RFSEAT3      _FLSHOT6       _PNEUMO2       _AIDTST3
# count  328135.000000  116757.00000  116757.000000  296055.000000
# mean        1.882390       2.28991       2.406794       1.966675
# std         2.346068       2.51678       2.771851       1.434133
# min         1.000000       1.00000       1.000000       1.000000
# 25%         1.000000       1.00000       1.000000       1.000000
# 50%         1.000000       1.00000       1.000000       2.000000
# 75%         1.000000       2.00000       2.000000       2.000000
# max         9.000000       9.00000       9.000000       9.000000
#
# [8 rows x 322 columns]

# %% [markdown]
# First remove every column with more than 30% of values missing. For categorical values even with high missing data we can add a missing label but we can see that all those columns are all float value.

# %%
df.loc[:, (df.isnull().mean() > 0.3)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328135 entries, 0 to 328134
# Columns: 177 entries, CTELENUM to _PNEUMO2
# dtypes: float64(177)
# memory usage: 443.1 MB

# %%
threshold = 0.3  # 30%
df = df.loc[:, df.isnull().mean() <= threshold]

# %% [markdown]
# In the missing columns none of them are categorical so we cant easily "fix" the data by giving an unknown category (probably already done). We can check the correlation with the target for the columns with 5-30% missing data.

# %%
from scipy import stats
import numpy as np

# Merge x_train with target column from y_train using 'id'
df_temp = df.merge(y_train[['Id', '_MICHD']], on='Id', how='inner')

# Identify columns with >5% missing
missing_pct = df.isna().mean() * 100
cols_missing_over_5 = missing_pct[missing_pct>5].index

# Compute p-values for correlation with the target
pvalues = {}
for col in cols_missing_over_5:
    # Remove NaN values for both column and target
    valid_mask = df_temp[col].notna() & df_temp['_MICHD'].notna()
    if valid_mask.sum() > 0:
        corr, pval = stats.pearsonr(df_temp.loc[valid_mask, col],
                                    df_temp.loc[valid_mask, '_MICHD'])
        pvalues[col] = pval

pvalues = pd.Series(pvalues).sort_values(ascending=False)
pvalues
# Out:
# FRUITJU1     3.325802e-01
# BEANDAY_     8.378857e-05
# ORNGDAY_     1.586959e-11
# _FRUTSUM     1.986216e-17
# VEGEDA1_     2.632514e-21
# FVORANG      7.520909e-24
# VEGETAB1     1.573079e-27
# SEATBELT     2.373590e-29
# FTJUDA1_     5.722777e-32
# FVBEANS      1.318559e-38
# _AIDTST3     1.215514e-44
# HIVTST6      4.184353e-48
# STRFREQ_     2.946199e-52
# FRUIT1       3.273469e-55
# FRUTDA1_     3.399965e-69
# _VEGESUM     1.367051e-72
# GRENDAY_    2.067440e-126
# EXERANY2    4.093965e-150
# FVGREEN     2.234687e-164
# FLUSHOT6    2.018687e-186
# WTKG3       7.770418e-191
# _BMI5       2.755242e-195
# _BMI5CAT    5.319891e-251
# STRENGTH    7.545842e-286
# CHOLCHK     1.397524e-318
# PNEUVAC3     0.000000e+00
# TOLDHI2      0.000000e+00
# _CHISPNC     0.000000e+00
# _RFCHOL      0.000000e+00
# dtype: float64

# %%
df = df.drop("FRUITJU1", axis=1)

# %% [markdown]
# Next we can remove a couple more columns that are highly correlated to reduce redundancy,

# %%
missing_pct = df.isna().mean() * 100
cols_missing_over_5 = missing_pct[missing_pct > 5].index.tolist()
df_subset = df.copy()[cols_missing_over_5].dropna()
corr_matrix = df_subset.corr()

# Find highly correlated pairs (correlation > 0.8)
print("\nHighly correlated pairs (|correlation| > 0.8):")
high_corr_pairs = []
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if abs(corr_matrix.iloc[i, j]) > 0.8:
            high_corr_pairs.append({
                'Feature 1': corr_matrix.columns[i],
                'Feature 2': corr_matrix.columns[j],
                'Correlation': corr_matrix.iloc[i, j]
            })

if high_corr_pairs:
    high_corr_df = pd.DataFrame(high_corr_pairs)
    print(high_corr_df.to_string(index=False))
else:
    print("No pairs found with |correlation| > 0.8")
# Out:
# Highly correlated pairs (|correlation| > 0.8):
# Feature 1 Feature 2  Correlation
#   HIVTST6  _AIDTST3     0.990376
#     WTKG3     _BMI5     0.875093
#  FRUTDA1_  _FRUTSUM     0.878864

# %%
df[['FRUTDA1_', '_FRUTSUM', 'HIVTST6', '_AIDTST3']]
# Out:
#         FRUTDA1_  _FRUTSUM  HIVTST6  _AIDTST3
# 0           0.71      0.71      2.0       2.0
# 1            NaN       NaN      NaN       NaN
# 2           2.00      2.03      2.0       2.0
# 3           0.00      0.00      2.0       2.0
# 4           0.50      1.50      2.0       2.0
# ...          ...       ...      ...       ...
# 328130      1.00      1.00      2.0       2.0
# 328131      1.00      1.00      1.0       1.0
# 328132      1.00      1.00      2.0       2.0
# 328133      0.07      0.07      2.0       2.0
# 328134      3.00      4.00      2.0       2.0
#
# [328135 rows x 4 columns]

# %% [markdown]
# No difference between dropping HIVTST6 or _AIDTST3. _FRUITSUM is a sum variable that summarizes multiple other factors, we will keep FRUTDA1 which is more isolated. BMI is a sum variable, we will keep WTkG3 the absolute weight.

# %%
df = df.drop(["HIVTST6", "_BMI5", "_FRUTSUM"], axis=1)

# %% [markdown]
# Now that we've reduced the number of columns with missing data, interpolate missing data based on skew, high skew data use media, low skew use mean.

# %%
# Interpolate missing values based on skewness recommendations
from scipy.stats import skew

# Get columns with missing values
cols_with_missing = df.columns[df.isnull().any()].tolist()

# Separate columns by interpolation method based on skewness
median_cols = []
mean_cols = []

for col in cols_with_missing:
    skewness = skew(df[col].dropna())
    if abs(skewness) > 0.5:
        median_cols.append(col)
    else:
        mean_cols.append(col)

# Fill with median for skewed columns (correct way)
for col in median_cols:
    df[col] = df[col].fillna(df[col].median())

# Fill with mean for normally distributed columns (correct way)
for col in mean_cols:
    df[col] = df[col].fillna(df[col].mean())

print(f"Filled {len(median_cols)} columns with median")
print(f"Filled {len(mean_cols)} columns with mean")
# Out:
# Filled 53 columns with median
# Filled 5 columns with mean
#
# Remaining missing values: 0
